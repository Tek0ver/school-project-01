# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup

# %%
url = "https://www.lemonde.fr/recherche/"

# %%
url = "https://www.lemonde.fr/recherche/?search_keywords=ukraine"

# %%
response = requests.get("http://localhost:8050/render.html",
                        params={
                            'url': url,
                            'wait': 2})

# %%
response.text
# Out:
# '<!DOCTYPE html><html lang="fr" prefix="og: http://ogp.me/ns#"><head> <meta charset="UTF-8"> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no"> <meta name="referrer" content="no-referrer-when-downgrade"> <meta name="theme-color" content="#ffffff">     <link rel="preload" href="//www.lemonde.fr/dist/assets/fonts/marr-sans-cond/MarrSansCondensed-Medium-Web.woff2" as="font" type="font/woff2" crossorigin="">  <link rel="manifest" href="/manifest.json"> <script>\nvar lmd={"consent":{"version":1},"context":{"aec":false,"pageType":"recherche"},"user":false,"lang":"fr","projectLangFR":true,"hosts":{"lemonde":"www.lemonde.fr","sf_secure":"secure.lemonde.fr","forecast":"forecast.lemonde.fr"},"env":"prd","analytics":{"oneNext":{"id":"244044216595"},"fba":{"id":"122349388153507","idCommunication":"607705069438811","contentType":"element-recherche"},"amplitude":{"id":"7dec6d6e90d5288af6e9a882f8def199","arvat
# ...

# %%
soup = BeautifulSoup(response.text, 'html.parser')

# %%
# soup.find_all("a", class_="sister")

# %%
soup.find_all("h3")
# Out:
# [<h3 class="footer__category-title">Services Le Monde</h3>,
#  <h3 class="footer__category-title">Guides d'achat Le Monde</h3>,
#  <h3 class="footer__category-title">Codes promo</h3>,
#  <h3 class="footer__category-title">Le Monde à l'international</h3>,
#  <h3 class="footer__category-title">Services Partenaires</h3>,
#  <h3 class="footer__category-title">Sites du groupe</h3>,
#  <h3 class="footer__category-title">Informations légales le Monde</h3>]
