# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('le_monde.csv')

# %%
data
# Out:
#                                                 title                 date
# 0   Guerre en Ukraine, en direct : incertitude sur...                  NaN
# 1   « De guerre en guerre. De 1940 à l’Ukraine » :...  2023-01-12 20:00:00
# 2   L’Afrique subit toujours l’impact de la guerre...                  NaN
# 3   Guerre en Ukraine : cinq réfugiés russes coinc...                  NaN
# 4   Dans l’Arctique, la guerre en Ukraine rebat le...                  NaN
# 5   Human Rights Watch se félicite de la mobilisat...  2023-01-12 06:30:00
# 6   Guerre en Ukraine, en direct : Volodymyr Zelen...  2023-01-12 19:14:00
# 7   Guerre en Ukraine : Kiev et ses alliés redoute...  2023-01-12 05:20:00
# 8   Valéri Guerassimov, chef d’état-major de l’arm...  2023-01-12 11:08:00
# 9   Guerre en Ukraine : comprendre la bataille de ...                  NaN
# 10  Guerre en Ukraine : les combats actuels près d...  2023-01-12 06:06:00
# ...

# %%
data['date'][1]
# Out:
# '2023-01-12 20:00:00'

# %%
data['date'][1][5:7]
# Out:
# '01'

# %%
type(data['date'][1])
# Out:
# str

# %%
def convert_date(date):
    try:
        return int(date[5:7])
    except:
        return 0

# %%
data['date'] = data['date'].apply(convert_date)

# %%
data
# Out:
#                                                 title  date
# 0   Guerre en Ukraine, en direct : incertitude sur...     0
# 1   « De guerre en guerre. De 1940 à l’Ukraine » :...     1
# 2   L’Afrique subit toujours l’impact de la guerre...     0
# 3   Guerre en Ukraine : cinq réfugiés russes coinc...     0
# 4   Dans l’Arctique, la guerre en Ukraine rebat le...     0
# 5   Human Rights Watch se félicite de la mobilisat...     1
# 6   Guerre en Ukraine, en direct : Volodymyr Zelen...     1
# 7   Guerre en Ukraine : Kiev et ses alliés redoute...     1
# 8   Valéri Guerassimov, chef d’état-major de l’arm...     1
# 9   Guerre en Ukraine : comprendre la bataille de ...     0
# 10  Guerre en Ukraine : les combats actuels près d...     1
# 11  Guerre en Ukraine en direct : le Groupe Wagner...     1
# 12  Guerre en Ukraine : les Ukrainiens toujours au...     0
# 13  Guerre en Ukraine : « C’est la bataille de Ver...     0
# 14  Guerre en Ukraine : la Russie ne contrôle plus...     1
# ...

# %%
plt.hist(data['date'])
# Out:
# (array([ 7.,  0., 17.,  0.,  0.,  0.,  0.,  0.,  0.,  2.]),
#  array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ]),
#  <BarContainer object of 10 artists>)
